# %% [markdown]
# **Lane detection model using Hough Transform**
#
# ---

# %%
import numpy as np
import cv2 as cv2


# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

#Routine to fix 
def fixColor(image):
    return(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# **FOR IMAGE 1:**

# %%
image1 = cv2.imread('/content/images/test_img01.jpeg')
plt.imshow(fixColor(image1))

# %%
gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (11,11), 0)
plt.imshow(fixColor(gray))

# %%
edges = cv2.Canny(gray, 50, 200)
plt.imshow(edges)

# %%
lines = cv2.HoughLinesP(edges, rho=1, theta=np.pi/180, threshold = 100, minLineLength=5, maxLineGap=250)
for line in lines:
    x1, y1, x2, y2 = line[0]
    if (y1 > 400 or y2 > 400): #Filter out the lines in the top of the image
        cv2.line(image1, (x1, y1), (x2, y2), (255, 0, 0), 3)
plt.imshow(fixColor(image1))

# %% [markdown]
# **FOR IMAGE 2:**

# %%
image2 = cv2.imread('/content/images/test_img02.jpeg')
plt.imshow(fixColor(image2))

# %%
gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (11,11), 0)
plt.imshow(fixColor(gray))

# %%
edges = cv2.Canny(gray, 50, 200)
plt.imshow(edges)

# %%
lines = cv2.HoughLinesP(edges, rho=1, theta=np.pi/180, threshold = 100, minLineLength=5, maxLineGap=250)
for line in lines:
    x1, y1, x2, y2 = line[0]
    if (y1 > 400 or y2 > 400): #Filter out the lines in the top of the image
        cv2.line(image2, (x1, y1), (x2, y2), (255, 0, 0), 3)
plt.imshow(fixColor(image2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e920119fe212> in <module>
#       1 lines = cv2.HoughLinesP(edges, rho=1, theta=np.pi/180, threshold = 100, minLineLength=5, maxLineGap=250)
# ----> 2 for line in lines:
#       3     x1, y1, x2, y2 = line[0]
#       4     if (y1 > 400 or y2 > 400): #Filter out the lines in the top of the image
#       5         cv2.line(image2, (x1, y1), (x2, y2), (255, 0, 0), 3)
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# **FOR IMAGE 3:**

# %%
image3 = cv2.imread('/content/images/test_img03.jpeg')
plt.imshow(fixColor(image3))

# %%
gray = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (11,11), 0)
plt.imshow(fixColor(gray))

# %%
edges = cv2.Canny(gray, 50, 200)
plt.imshow(edges)

# %%
lines = cv2.HoughLinesP(edges, rho=1, theta=np.pi/180, threshold = 100, minLineLength=5, maxLineGap=250)
for line in lines:
    x1, y1, x2, y2 = line[0]
    if (y1 > 400 or y2 > 400): #Filter out the lines in the top of the image
        cv2.line(image3, (x1, y1), (x2, y2), (255, 0, 0), 3)
plt.imshow(fixColor(image3))

# %% [markdown]
# **HERE WE HAVE GOT SUCCESSFUL RESULT ONLY FOR IMAGE 3**
#
# ---
